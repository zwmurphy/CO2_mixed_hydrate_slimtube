# %% [markdown]
# ### Experiment comparison
# #### Zach Murphy, 7-25-2022

# %%
#imports
import numpy as np
import math as m
import pandas as pd
import matplotlib.pyplot as plt
import gas_density as rho_g_fun # Temp IN C and Pressure in PSI
# %matplotlib inline
from matplotlib.offsetbox import AnchoredText

# %%
# IMPORT DATA
df=pd.read_excel('ST140_gas.xlsx')
df2=pd.read_excel('GC_results.xlsx')
df3=pd.read_excel('GC_results_900.xlsx')
df4=pd.read_excel('GC_results_120.xlsx')
df5=pd.read_excel('Hydrate_free_sim.xlsx')
dfmodel=pd.read_excel('CO2_CH4_Simulation_900.xlsx')
dfm2=pd.read_excel('CO2_CH4_Simulation_2-10-23.xlsx')
df['P avg']=(df['P up']+df['P down'])/2
df['Gas out']=df['Gas out']*1.1
df['PV in']=df['Gas in']/4.96
df['PV out']=df['Gas out']/4.96

# %%
fig=plt.figure(figsize=(18,15))
plt.rcParams['font.size']=18
sharex='True'

plt1=fig.add_subplot(3,1,1)
plt1.plot(df2['PV out'],df2['CH4'],'-o',markersize=10,color='red',label='CH4')
plt1.plot(df2['PV out'],df2['N2'],'-o',markersize=10,color='purple',label='N2')
plt1.plot(df2['PV out'],df2['CO2'],'-o',markersize=10,color='green',label='CO2')


plt1.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt1.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt1.annotate("Experiment: S$_h$=0.25", xy=(.9, 0.5), xycoords="data",va="center", 
             ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt1.annotate("N$_2$",xy=(.52, 0.58), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CO$_2$",xy=(.52, 0.1), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CH$_4$",xy=(.52,.35), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("A)",xy=(1.047, 0.9), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"))

#plt.xlabel('PV gas out')
plt.xlim([0,1.07])
plt.ylim([0,1])
plt.yticks([0,.2,.4,.6,.8,1])
plt.ylabel('Effluent composition')
#plt.legend(loc='best')

plt2=fig.add_subplot(3,1,2,sharex=plt1)
plt2.plot(dfmodel['Time']-.05,dfmodel['X_CH4'],'-',linewidth=3,color='red',label='CH4')
plt2.plot(dfmodel['Time']-.05,dfmodel['X_N2'],'-',linewidth=3,color='purple',label='N2')
plt2.plot(dfmodel['Time']-.05,dfmodel['X_CO2'],'-',linewidth=3,color='green',label='CO2')

plt2.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt2.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt2.annotate("Model: PT-1", xy=(.9, 0.5), xycoords="data",va="center", 
             ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt2.annotate("N$_2$",xy=(.52, 0.8), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CO$_2$",xy=(.52, 0.2), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CH$_4$",xy=(.52, 0), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)


plt2.annotate("B)",xy=(1.047, 0.9), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"))

plt.ylim([0,1])
plt.yticks([0,.2,.4,.6,.8,1])
plt.ylabel('Effluent composition')
#plt.legend(loc='right')

plt2=fig.add_subplot(3,1,3,sharex=plt1)
plt2.plot(dfm2['Time']-0.19,dfm2['X_CH4'],'-',linewidth=3,color='red',label='CH4')
plt2.plot(dfm2['Time']-0.19,dfm2['X_N2'],'-',linewidth=3,color='purple',label='N2')
plt2.plot(dfm2['Time']-0.19,dfm2['X_CO2'],'-',linewidth=3,color='green',label='CO2')

plt2.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt2.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt2.annotate("Model: PT-2", xy=(.9, 0.5), xycoords="data",va="center", 
             ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt2.annotate("N$_2$",xy=(.52, 0.8), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CO$_2$",xy=(.52, 0.2), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CH$_4$",xy=(.52, 0), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("C)",xy=(1.047, 0.9), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"))
plt.xlabel('PV gas out')
plt.ylim([0,1])
plt.yticks([0,.2,.4,.6,.8,1])
plt.ylabel('Effluent composition')
#plt.legend(loc='right')
# Out:
# Text(0, 0.5, 'Effluent composition')

# %%
fig=plt.figure(figsize=(17,10))
plt.rcParams['font.size']=25
sharex='True'

plt1=fig.add_subplot(1,1,1)
plt1.plot(df2['PV out'],df2['CH4'],'-o',markersize=10,color='red',label='CH4')
plt1.plot(df2['PV out'],df2['N2'],'-o',markersize=10,color='purple',label='N2')
plt1.plot(df2['PV out'],df2['CO2'],'-o',markersize=10,color='green',label='CO2')

plt1.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt1.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt1.annotate("Hydrate (25%)", xy=(1.7, 0.5), xycoords="data",va="center", 
              ha="center",size=30,bbox=dict(boxstyle="square", fc="w"))

plt1.annotate("Injection Ratio",xy=(1.1, 0.8), xycoords='data',xytext=(1.1, 0.5), textcoords='data',size=20, va="center", ha="center",
                  bbox=dict(boxstyle="sawtooth", fc="w"),
                  arrowprops=dict(arrowstyle="simple",
                                  fc="k"),)

plt1.annotate("Injection Ratio",xy=(1.1, 0.2), xycoords='data',
                  xytext=(1.1, 0.5), textcoords='data',
                  size=25, va="center", ha="center",
                  bbox=dict(boxstyle="sawtooth", fc="w"),
                  arrowprops=dict(arrowstyle="simple",fc="k"),)

plt1.annotate("N$_2$",xy=(1.35, 0.77), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CO$_2$",xy=(1.35, 0.17), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CH$_4$",xy=(1.35, .06), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)


plt.xlabel('PV gas out')
plt.xlim([0,2])
plt.ylim([0,1])
plt.ylabel('Effluent composition')#plt.ylabel('Gas composition, (mol%)')
#plt.legend(loc='best')
# Out:
# Text(0, 0.5, 'Effluent composition')

# %%
fig=plt.figure(figsize=(18,15))
plt.rcParams['font.size']=20
sharex='True'

plt1=fig.add_subplot(3,1,1)
plt1.plot(df2['PV out'],df2['CH4'],'-o',markersize=10,color='red',label='CH4')
plt1.plot(df2['PV out'],df2['N2'],'-o',markersize=10,color='purple',label='N2')
plt1.plot(df2['PV out'],df2['CO2'],'-o',markersize=10,color='green',label='CO2')

plt1.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt1.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt1.annotate("Hydrate (25%)", xy=(1.75, 0.5), xycoords="data",va="center", 
              ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt1.annotate("Injection Ratio",xy=(1.1, 0.8), xycoords='data',xytext=(1.1, 0.5), textcoords='data',size=20, va="center", ha="center",
                  bbox=dict(boxstyle="sawtooth", fc="w"),
                  arrowprops=dict(arrowstyle="simple",
                                  fc="k"),)

plt1.annotate("Injection Ratio",xy=(1.1, 0.2), xycoords='data',
                  xytext=(1.1, 0.5), textcoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="sawtooth", fc="w"),
                  arrowprops=dict(arrowstyle="simple",fc="k"),)

plt1.annotate("N$_2$",xy=(1.35, 0.77), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CO$_2$",xy=(1.35, 0.17), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CH$_4$",xy=(1.35, .06), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)
plt1.annotate("A)",xy=(1.95, .92), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

#plt.xlabel('PV gas out')
plt.xlim([0,2])
plt.ylim([0,1])
plt.ylabel('Effluent composition')#plt.ylabel('Gas composition, (mol%)')
#plt.legend(loc='best')

plt2=fig.add_subplot(3,1,2,sharex=plt1)
plt2.plot(df3['PV out'],df3['CH4'],'-o',markersize=10,color='red',label='CH4')
plt2.plot(df3['PV out'],df3['N2'],'-o',markersize=10,color='purple',label='N2')
plt2.plot(df3['PV out'],df3['CO2'],'-o',markersize=10,color='green',label='CO2')
plt2.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt2.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt2.annotate("Hydrate (33%)", xy=(1.75, 0.5), xycoords="data",
                  va="center", ha="center",size=25,
                  bbox=dict(boxstyle="square", fc="w"))

plt2.annotate("N$_2$",xy=(.9, 0.64), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CO$_2$",xy=(.9, 0.12), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CH$_4$",xy=(.9, .25), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)
plt2.annotate("B)",xy=(1.95, .92), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt.ylim([0,1])

#plt.xlabel('PV gas out')
plt.ylabel('Effluent composition')#, (mol%)')
#plt.legend(loc='best')

plt3=fig.add_subplot(3,1,3,sharex=plt1)
plt3.plot(df4['PV out'],df4['CH4'],'-o',markersize=10,color='red',label='CH4')
plt3.plot(df4['PV out'],df4['N2'],'-o',markersize=10,color='purple',label='N2')
plt3.plot(df4['PV out'],df4['CO2'],'-o',markersize=10,color='green',label='CO2')
plt3.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt3.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt3.annotate("Hydrate Free", xy=(1.75, 0.5), xycoords="data",
                  va="center", ha="center",size=25,
                  bbox=dict(boxstyle="square", fc="w"))

plt3.annotate("N$_2$",xy=(.9, 0.8), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt3.annotate("CO$_2$",xy=(.9, 0.2), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt3.annotate("CH$_4$",xy=(.9, 0), xycoords='data',
                  size=15, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)
plt3.annotate("C)",xy=(1.95, .92), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt.ylim([0,1])

plt.xlabel('PV gas out')
plt.ylabel('Effluent composition')#plt.ylabel('Gas composition, (mol%)')
#plt.legend(loc='best')
# Out:
# Text(0, 0.5, 'Effluent composition')

# %%
fig=plt.figure(figsize=(14,8))
plt.rcParams['font.size']=18
sharex='True'

plt3=fig.add_subplot(1,1,1)
plt3.plot(df2['PV out'],df2['CO2-N2'],'-o',markersize=6,linewidth=2,color='black',label='Sh=0.25')
plt3.plot(df3['PV out'],df3['CO2-N2'],'--o',markersize=6,linewidth=2,color='black',label='Sh=0.33')
plt3.plot(df4['PV out'],df4['CO2-N2'],':o',markersize=6,linewidth=2,color='black',label='Sh=0')
plt3.axhline(.25,0,25,linestyle='solid',linewidth=3,color='red')
#plt3.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt.xlim([0,2])

plt3.annotate("Injection Ratio",xy=(1.6, 0.25), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt3.annotate("Hydrate (25%)",xy=(1.75, 0.21), xycoords='data',
                  size=20, va="center", ha="center", rotation=2,
                  bbox=dict(boxstyle="square", fc="w"),)


plt3.annotate("Hydrate Free",xy=(.25, 0.198), xycoords='data',
                  xytext=(.2, 0.28), textcoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),
                  arrowprops=dict(arrowstyle="simple",fc="k"),)

plt3.annotate("Hydrate (33%)",xy=(.65, 0.18), xycoords='data',
                  xytext=(.65, 0.22), textcoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),
                  arrowprops=dict(arrowstyle="simple",fc="k"),)

plt.ylim([0,.3])
plt.xlabel('PV gas out')
plt.ylabel('CO$_2$/N$_2$ Ratio')
#plt.legend(loc='best')
# Out:
# Text(0, 0.5, 'CO$_2$/N$_2$ Ratio')

# %%
fig=plt.figure(figsize=(18,15))
plt.rcParams['font.size']=18
sharex='True'

plt1=fig.add_subplot(4,1,1)
plt1.plot(df2['PV out'],df2['CH4'],'-o',markersize=10,color='red',label='CH4')
plt1.plot(df2['PV out'],df2['N2'],'-o',markersize=10,color='purple',label='N2')
plt1.plot(df2['PV out'],df2['CO2'],'-o',markersize=10,color='green',label='CO2')


plt1.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt1.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt1.annotate("Experiment: S$_h$=0.25", xy=(.9, 0.5), xycoords="data",va="center", 
             ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt1.annotate("N$_2$",xy=(.52, 0.58), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CO$_2$",xy=(.52, 0.1), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CH$_4$",xy=(.52,.35), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt.xlabel('PV gas out')
plt.xlim([0,1.07])
plt.ylim([0,1])
plt.ylabel('Gas composition, (mol%)')
#plt.legend(loc='best')

plt2=fig.add_subplot(4,1,2,sharex=plt1)
plt2.plot(dfm2['Time'],dfm2['X_CH4'],'-',linewidth=3,color='red',label='CH4')
plt2.plot(dfm2['Time'],dfm2['X_N2'],'-',linewidth=3,color='purple',label='N2')
plt2.plot(dfm2['Time'],dfm2['X_CO2'],'-',linewidth=3,color='green',label='CO2')

plt2.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt2.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt2.annotate("Model: S$_h$=0.25", xy=(.9, 0.5), xycoords="data",va="center", 
             ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt2.annotate("N$_2$",xy=(.52, 0.8), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CO$_2$",xy=(.52, 0.2), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CH$_4$",xy=(.52, 0), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)
plt.xlabel('PV gas out')
plt.ylim([0,1])
plt.ylabel('Gas composition, (mol%)')
#plt.legend(loc='right')


plt3=fig.add_subplot(4,1,3,sharex=plt1)
plt3.axhline(.25,0,25,linestyle='solid',linewidth=3,color='red')
plt3.plot(df2['PV out'],df2['CO2-N2'],'-',linewidth=3,color='black',label='Sh=0.25')
#plt3.plot(df3['PV out'],df3['CO2-N2'],'--',linewidth=2,color='black',label='Sh=0.33')
plt3.plot(dfm2['Time'],dfm2['X_CO2']/dfm2['X_N2'],':',linewidth=3,color='black',label='Sh=0')


#plt3.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt3.annotate("Injection Ratio",xy=(.1, 0.25), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt3.annotate("Experiment",xy=(.75, 0.165), xycoords='data',
                  xytext=(.75, 0.1), textcoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),
                  arrowprops=dict(arrowstyle="simple",fc="k"),)


plt3.annotate("Model",xy=(.365,0.15), xycoords='data',
                  xytext=(.29 ,.15), textcoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),
                  arrowprops=dict(arrowstyle="simple",fc="k"),)

plt.ylim([0,.4])

plt.xlabel('PV gas out')
plt.ylabel('CO$_2$/N$_2$ Ratio')

plt4=fig.add_subplot(4,1,4,sharex=plt1)
#plt4.axhline(.25,0,25,linestyle='solid',linewidth=3,color='red')
plt4.plot(df2['PV out'],df2['CH4-N2'],'-',linewidth=3,color='black',label='Sh=0.25')
#plt3.plot(df3['PV out'],df3['CO2-N2'],'--',linewidth=2,color='black',label='Sh=0.33')
plt4.plot(dfm2['Time'],dfm2['X_CH4']/dfm2['X_N2'],':',linewidth=3,color='black',label='Sh=0')
#plt.legend(loc='best')

# %%
# Out:
# Text(0, 0.5, 'Effluent composition')

# %%
fig=plt.figure(figsize=(18,15))
plt.rcParams['font.size']=18
sharex='True'

plt1=fig.add_subplot(4,1,1)
plt1.plot(df2['PV out'],df2['CH4'],'-o',markersize=10,color='red',label='CH4')
plt1.plot(df2['PV out'],df2['N2'],'-o',markersize=10,color='purple',label='N2')
plt1.plot(df2['PV out'],df2['CO2'],'-o',markersize=10,color='green',label='CO2')


plt1.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt1.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt1.annotate("Experiment: S$_h$=0.25", xy=(.9, 0.5), xycoords="data",va="center", 
             ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt1.annotate("N$_2$",xy=(.52, 0.58), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CO$_2$",xy=(.52, 0.1), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("CH$_4$",xy=(.52,.35), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt1.annotate("A)",xy=(1.047, 0.88), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"))

#plt.xlabel('PV gas out')
plt.xlim([0,1.07])
plt.ylim([0,1])
plt.yticks([0,.2,.4,.6,.8,1])
plt.ylabel('Effluent composition')
#plt.legend(loc='best')

plt2=fig.add_subplot(4,1,2,sharex=plt1)
plt2.plot(dfmodel['Time'],dfmodel['X_CH4'],'-',linewidth=3,color='red',label='CH4')
plt2.plot(dfmodel['Time'],dfmodel['X_N2'],'-',linewidth=3,color='purple',label='N2')
plt2.plot(dfmodel['Time'],dfmodel['X_CO2'],'-',linewidth=3,color='green',label='CO2')

plt2.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt2.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt2.annotate("Model: S$_h$=0.25", xy=(.9, 0.5), xycoords="data",va="center", 
             ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt2.annotate("N$_2$",xy=(.52, 0.8), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CO$_2$",xy=(.52, 0.2), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CH$_4$",xy=(.52, 0), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)


plt2.annotate("B)",xy=(1.047, 0.88), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"))

plt.ylim([0,1])
plt.yticks([0,.2,.4,.6,.8,1])
plt.ylabel('Effluent composition')
#plt.legend(loc='right')

plt2=fig.add_subplot(4,1,3,sharex=plt1)
plt2.plot(dfm2['Time'],dfm2['X_CH4'],'-',linewidth=3,color='red',label='CH4')
plt2.plot(dfm2['Time'],dfm2['X_N2'],'-',linewidth=3,color='purple',label='N2')
plt2.plot(dfm2['Time'],dfm2['X_CO2'],'-',linewidth=3,color='green',label='CO2')

plt2.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt2.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt2.annotate("Model: S$_h$=0", xy=(.9, 0.5), xycoords="data",va="center", 
             ha="center",size=25,bbox=dict(boxstyle="square", fc="w"))

plt2.annotate("N$_2$",xy=(.52, 0.8), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CO$_2$",xy=(.52, 0.2), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("CH$_4$",xy=(.52, 0), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt2.annotate("C)",xy=(1.047, 0.88), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"))
#plt.xlabel('PV gas out')
plt.ylim([0,1])
plt.yticks([0,.2,.4,.6,.8,1])
plt.ylabel('Effluent composition')
#plt.legend(loc='right')


plt3=fig.add_subplot(4,1,4,sharex=plt1)
plt3.axhline(.25,0,25,linestyle='solid',linewidth=3,color='red')
plt3.plot(df2['PV out'],df2['CO2-N2'],'-',linewidth=3,color='black',label='Sh=0.25')
#plt3.plot(df3['PV out'],df3['CO2-N2'],'--',linewidth=2,color='black',label='Sh=0.33')
plt3.plot(dfmodel['Time'],dfmodel['X_CO2']/dfmodel['X_N2'],':',linewidth=3,color='black',label='Sh=0')
plt3.plot(dfm2['Time'],dfm2['X_CO2']/dfm2['X_N2'],':',linewidth=3,color='black',label='Sh=0')
plt3.plot(df5['Time'],df5['X_CO2']/df5['X_N2'],':',linewidth=3,color='black',label='Sh=0')

#plt3.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt3.annotate("Injection Ratio",xy=(.1, 0.25), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),)

plt3.annotate("Experiment",xy=(.75, 0.165), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"))


plt3.annotate("Model: S$_h$=0",xy=(.25,0.15), xycoords='data',
                  xytext=(.14 ,.15), textcoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),
                  arrowprops=dict(arrowstyle="simple",fc="k"),)

plt3.annotate("Model: S$_h$=0.25",xy=(.35,0.16), xycoords='data',
                  xytext=(.35 ,.33), textcoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"),
                  arrowprops=dict(arrowstyle="simple",fc="k"),)

plt3.annotate("D)",xy=(1.047, 0.35), xycoords='data',
                  size=20, va="center", ha="center",
                  bbox=dict(boxstyle="square", fc="w"))

plt.ylim([0,.4])

plt.xlabel('PV gas out')
plt.ylabel('CO$_2$/N$_2$ Ratio')
#plt.legend(loc='best')
# Out:
# Text(0, 0.5, 'CO$_2$/N$_2$ Ratio')

# %%
fig=plt.figure(figsize=(18,15))
plt.rcParams['font.size']=18
sharex='True'

plt1=fig.add_subplot(3,1,1)
plt1.plot(df2['PV out'],df2['CH4'],'-o',markersize=10,color='red',label='CH4')
plt1.plot(df2['PV out'],df2['N2'],'-o',markersize=10,color='purple',label='N2')
plt1.plot(df2['PV out'],df2['CO2'],'-o',markersize=10,color='green',label='CO2')

plt1.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt1.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')


plt.xlim([0,2])
plt.ylim([0,1])
plt.ylabel('Gas composition, (mol%)')
plt.legend(loc='best')

plt2=fig.add_subplot(3,1,2,sharex=plt1)
plt2.plot(df3['PV out'],df3['CH4'],'-o',markersize=10,color='red',label='CH4')
plt2.plot(df3['PV out'],df3['N2'],'-o',markersize=10,color='purple',label='N2')
plt2.plot(df3['PV out'],df3['CO2'],'-o',markersize=10,color='green',label='CO2')
plt2.axhline(.8,0,25,linestyle='dashed',linewidth=2,color='purple')
plt2.axhline(.2,0,25,linestyle='dashed',linewidth=2,color='Green')

plt.ylim([0,1])

plt.xlabel('PV gas out')
plt.ylabel('Gas composition, (mol%)')
plt.legend(loc='best')

plt3=fig.add_subplot(3,1,3,sharex=plt1)
plt3.axhline(.25,0,25,label='Injection Ratio',linewidth=2,color='Black')
plt3.plot(df2['PV out'],df2['CO2-N2'],'--',color='black',linewidth=2,label='Effluent Ratio: Sh=0.25')
plt3.plot(df3['PV out'],df3['CO2-N2'],':',color='black',linewidth=2,label='Effluent Ratio: Sh=0')


plt.ylim([0,.5])

plt.xlabel('PV gas out')
plt.ylabel('CO2/N2 Ratio')
plt.legend(loc='best')
